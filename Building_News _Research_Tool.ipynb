# %% [markdown]
# #### Task 1.1: Install Required Libraries

# %%
pip install newsapi-python
# Out:
# Collecting newsapi-python
#   Using cached newsapi_python-0.2.7-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: requests<3.0.0 in c:\users\hp\anaconda3\lib\site-packages (from newsapi-python) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (2024.8.30)
# Using cached newsapi_python-0.2.7-py2.py3-none-any.whl (7.9 kB)
# Installing collected packages: newsapi-python
# Successfully installed newsapi-python-0.2.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from newsapi import NewsApiClient

# %%
# Initialize the NewsAPI client with your API key
newsapi = NewsApiClient(api_key='712cb6c61d654ea2b1fbddf4de5b01c2')

# Define a function to get news articles based on a query
def get_news_articles(query):
    articles = newsapi.get_everything(q=query, language='en', sort_by='relevancy')
    return articles['articles']

# Example usage
query = 'technology'
articles = get_news_articles(query)
for article in articles:
    print(f"Title: {article['title']}")
    print(f"Description: {article['description']}\n")
# Out:
# Title: How China’s Propaganda and Surveillance Systems Really Operate
# Description: A series of corporate leaks show that Chinese technology companies function far more like their Western peers than one might imagine.
#
# Title: Researchers Tested Bite-Resistant Wetsuit Material With Great Whites and Tiger Sharks. Here’s What Happened
# Description: Unlike zebra-striped wetsuits or chunky deterrent bracelets, this technology goes back to the basics.
#
# Title: Hyundai’s Latest Concept Car Comes With Subtle ‘Star Wars’ References
# Description: Hyundai's Concept THREE serves as both a technology showcase and a nod to galaxy far, far away.
#
# Title: Honda’s Prelude returns as a 200-horsepower fake-shifting hybrid
# Description: Honda is bringing back the sporty Prelude as a technology-packed 200-horsepower hybrid to tug at nostalgia strings. It’s the first new Prelude in 25 years and the front-wheel-drive-coup antidote to crossover SUVs. Pricing hasn’t been announced but in Japan it…
#
# Title: Meta’s failed smart glasses demos had nothing to do with the Wi-Fi
# Description: Meta ran into some spectacularly embarrassing technical issues during the live demos of its new smart glasses this week, and now we know why. Andrew Bosworth, Meta’s chief technology officer, explained in an Instagram AMA why two notable demos — an influencer…
#
# Title: Silicon Valley’s latest argument against regulating AI: that would literally be the antichrist
# Description: In a four-part series of religious lectures in San Francisco, Peter Thiel - yes, that Peter Thiel - has argued that the End Times are night and that a biblical Antichrist - yes, that Antichrist - will come to earth in the form of onerous government regulation…
#
# Title: PlayStation’s new wireless speakers are for your desktop
# Description: Sony has announced new Pulse Elevate wireless speakers that you can use with your PS5, PC, Mac, and even a PlayStation Portal or smartphone. The company promises that they offer “lifelike desktop audio,” a built-in mic for voice chat, and support Sony’s PlayS…
#
# Title: Alien: Earth’s beefy tablets were inspired by Sony’s classic Watchman
# Description: Though technology has always played an important role in the Alien franchise, FX's Alien: Earth series is the first chapter to really dig into the inner workings of the tech companies responsible for unleashing xenomorphs onto humanity. To corporations like W…
#
# Title: Nvidia Is Not Happy With the Gain AI Act, Says As Much
# Description: It's no huge surprise that Nvidia, a Chinese corporation and currently the world's biggest company, would take aim at laws that might potentially restrict the competitiveness of foreign technology.
#
# Title: Business Insider reportedly tells journalists they can use AI to draft stories
# Description: Business Insider has told journalists they can use AI to create first drafts of stories and suggested it won’t notify readers that AI was used, according to Status, a newsletter covering the media industry. The policy makes the outlet one of the first to form…
#
# Title: Meta Connect 2025: the 6 biggest announcements
# Description: Meta just showed off all the latest in wearable technology, virtual reality, augmented reality, and more at its annual Connect keynote. In addition to the long-awaited reveal of Meta’s updated Ray-Ban smart glasses, the company had some other exciting surpris…
#
# Title: TCL’s 8-inch Nxtpaper tablet could lure you away from the color Kindle
# Description: TCL has put its Nxtpaper display technology, designed to be easy on the eyes like E Ink’s e-paper screens, in a slew of devices ranging from hefty 14-inch tablets to smartphones for kids. The new Tab 8 is the latest addition to TCL’s Nxtpaper lineup and with …
#
# Title: David Zaslav thinks HBO Max is ‘way underpriced’
# Description: Everyone’s favorite CEO, Warner Bros. Discovery head David Zaslav, thinks HBO Max is ripe for a price hike. Speaking at the Goldman Sachs Communacopia and Technology Conference (doesn’t that sound like a fun time?) Zaslav argued that his company’s premium out…
#
# Title: Nothing plans to launch ‘first AI-native devices next year’
# Description: London-based consumer tech startup Nothing has raised $200 million and vowed to usher in a new generation of “AI-native” devices running on operating systems that “are significantly different from the ones today.” In a press release that reads part ode to tec…
#
# Title: Volvo’s next-gen hyrbids will be American-made EREVs
# Description: As it struggles with declining sales and an uncertain regulatory environment, Volvo is hoping to realign its fortunes by overhauling its electric vehicle plans. And a big part of that is a bet on hybrid technology — or more specifically, extended-range electr…
#
# Title: How generative AI boosters are trying to break into Hollywood
# Description: This is The Stepback, a weekly newsletter breaking down one essential story from the tech world. For more on the intersection of entertainment and technology, follow Charles Pulliam-Moore. The Stepback arrives in our subscribers' inboxes at 8AM ET. Opt in for…
#
# Title: Larry Ellison’s quest to run the world
# Description: For most of his career Larry Ellison has been content to quietly let Oracle be the company, behind the company, behind the technology that makes headlines. Its biggest products being cloud computing and database products that it sells to enterprise customers …
#
# Title: Melania Trump’s AI Era Is Upon Us
# Description: The ever elusive first lady has emerged with a brief to exert thought leadership over AI, for the children. Some insiders are excited; others won't touch the subject with a 10-foot pole.
#
# Title: Apple Releases Safari Technology Preview 228 With Bug Fixes and Performance Improvements
# Description: Apple today released a new update for Safari Technology Preview, the experimental browser that was first introduced in March 2016. Apple designed ‌Safari Technology Preview‌ to allow users to test features that are planned for future release versions of the S…
#
# Title: VPNs Are in High Demand for These Main Reasons
# Description: A new study reveals how virtual private networks are expanding outside of the niche technology just for businesses.
#
# Title: Robotaxis as public transit? Waymo thinks so
# Description: Waymo is teaming up with tech transit startup Via to integrate its autonomous vehicles into city public transit networks, starting with a growing suburb of Phoenix. In Chandler, Arizona, Waymo’s robotaxis will soon join the town’s Flex microtransit service. U…
#
# Title: Amazon Unveils New Echo Speakers with Alexa+ AI and Omnisense Technology
# Description: Amazon today announced the launch of new Echo Dot Max, Echo Studio, Echo Show 8, and Echo Show 11 smart speakers, all of which are designed to work with Amazon's Alexa+ AI assistant.
#
#
#
#
#
# The new speakers have faster chips with AI acceleration, and a custom s…
#
# Title: Trump Shares Bizarre AI Video Promising Magic ‘Medbeds’ for Everyone
# Description: In a since-deleted Truth Social post, an AI version of Trump promised every American would soon have access to their very own medbed.
#
# Title: Meta AI just created the next evolution of the Photosphere
# Description: Hyperscape is a new technology from Meta that lets you scan and visit real world locations with hyper-realistic detail, all fully viewable in VR.
#
# Title: Energy Dept. tells employees not to use words including 'climate change' and 'green'
# Description: The banned words list applies to all work done at the largest federal funder of clean energy technology.
#
# Title: What to expect from Meta Connect 2025
# Description: Meta's annual technology conference, aptly titled Meta Connect, takes place on September 17 and 18 this year. Here's everything we expect to see.
#
# Title: Inside the Netherlands' greenhouse empire. Photos show how it became the world's second-largest agricultural exporter.
# Description: Photos show secrets behind the Netherlands' success as the world's second-largest agricultural exporter, focusing on pioneering greenhouse technology.
#
# Title: China is making big aircraft carrier moves. Here's how its flattops stack up against the US Navy.
# Description: China released footage of carrier Fujian's electromagnetic catapults last month, showing off a technology only the US had previously.
#
# Title: Welcome to Gizmodo’s New Look
# Description: Cleaner, faster, and easier to battle it out in the comments.
#
# Title: Werner Herzog on AI-Generated Movies: ‘They Look Completely Dead’
# Description: Herzog spoke with Conan O'Brien about the concept of truth and why AI is a "nemesis."
#
# Title: Microsoft is close to getting a giant new equity stake in OpenAI. It could be worth at least $150 billion.
# Description: Microsoft's unusual $1 billion bet on OpenAI back in 2019 has turned into one of the smartest investments in the history of technology.
#
# Title: Elon Musk's xAI accuses OpenAI of stealing trade secrets and targeting its employees in a new lawsuit
# Description: The legal battle between Elon Musk's xAI and Sam Altman's OpenAI just widened , with Musk accusing the ChatGPT maker of stealing technology.
#
# Title: Four Strategic Signals Technology Leaders Are Tuning In To - SPONSOR CONTENT FROM ARM
# Description: Sponsor content from ARM.
#
# Title: This could be 'the best growing technology company': Here's why
# Description: The artificial intelligence (AI) trade is top of mind for investors as US stocks (^DJI, ^GSPC, ^IXIC) trade at record highs. Niles Investment Management...
#
# Title: Is the 3I/ATLAS Comet Actually Alien Technology? No.
# Description: NASA has debunked the proposal of controversial astronomer Avi Loeb, who claimed the comet 3I/ATLAS could be malicious alien technology.
#
# Title: Microsoft is giving Copilot AI faces you can chat with
# Description: Microsoft is trying to make Copilot more approachable by giving the AI assistant an animated face to talk with. The experimental “Portraits” feature in Copilot Labs is currently available in the US, UK, and Canada, and provides 40 stylized human avatars that …
#
# Title: The hunger strike to end AI
# Description: On Guido Reichstadter's 17th day without eating, he said he was feeling alright - moving a little slower, but alright. Each day since September 2nd, Reichstadtler has appeared outside the San Francisco headquarters of AI startup Anthropic, standing from aroun…
#
# Title: What to expect from Nothing's ambitious AI-native OS set to launch in 2026
# Description: Nothing Phone, now valued at $1.3B after securing $200M in Series C funding, aims to revolutionize smartphone technology with a hyper-personalized AI operating system, promising a unique experience tailored to individual users and their needs.
#
# Title: Get Out of Technology
# Description: You heard there was money in tech. You heard there was status in tech. You showed up.
#
# Title: Livestream: Tech Went All in on Trump. Now What?
# Description: Our panel of experts discuss what the tech industry's allegiance to Trump really means, and how it will shape our future.
#
# Title: Creative Technology: The Sound Blaster
# Description: The Sound Blaster
#
# Title: Why US Power Bills Are Surging
# Description: Americans are paying more for electricity—and rates will keep rising. But after a period of pain, rates should level off as the benefits of a shift away from fossil fuels begin to be felt.
#
# Title: Google Warns That China-Linked Malware Will Haunt Networks for Years
# Description: Hackers were able to maintain access to their victims for an average 393 days.
#
# Title: Did a ‘KPop Demon Hunters’ Songwriter Really Use ChatGPT to Write ‘Soda Pop’?
# Description: The Saja Boys tune has come under scrutiny because of a seemingly mistranslated report.
#
# Title: Scientists Infuse Cement With Bacteria to Create Living Energy Device
# Description: The proof-of-concept material could one day be used to make more sustainable buildings.
#
# Title: Ted Cruz Wants to Help AI Companies Duck Regulations
# Description: Move fast and get permission to break stuff.
#
# Title: All New iPhone Models Now Feature ProMotion Displays
# Description: More than eight years after it introduced the technology, the entire new iPhone lineup features ProMotion display technology for the first time.
#
#
#
#
#
# ProMotion is Apple's name for its adaptive display technology that makes motion on screen appear smoother and…
#
# Title: Faisal Islam: Will the US tech bromance turn around the UK economy?
# Description: In the week the UK hosted Donald Trump for a second state visit, the country also rolled out the red carpet for US tech firms.
#
# Title: Why parents need to talk to their teens about AI — and how to start the conversation
# Description: Many teens are using artificial intelligence chatbots like ChatGPT for everything from homework to relationship advice. Experts say parents must lead the way in helping them understand the technology.
#
# Title: To save its unique and rare birds, New Zealand is turning to AI and genetic research
# Description: New Zealand is planning to eradicate millions of invasive animals that prey on the country's rare birds. The goal may not be possible, unless new technology can be developed to do it.
#
# Title: NPR's Student Podcast Challenge: Here are our fourth grade winners!
# Description: We heard fun and engaging podcasts on topics including how math teaching has evolved, what its like to disengage from technology, and, who has it better: kids or grownups?
#
# Title: The Verge’s guide to upgrading your fall
# Description: Autumn is a time for renewal. Summer, a time for vacations and relaxation, is over. And now, we must look to the start of a new school year and a renewed attention to work. It can sometimes be difficult to make the transition — many of us would rather spend a…
#
# Title: We Rarely Lose Technology (2023)
# Description: There are few forgotten inventions, and none that we might truly care about
#
# Title: The 'yogurt shop murders' have been solved after more than 30 years, Texas authorities say
# Description: The 'yogurt shop murders' have been solved with the help of DNA technology.
#
# Title: Huawei Unveils New AI Tech to Take on Nvidia
# Description: Huawei Technologies Co. unveiled new technology, including SuperPod cluster designs and AI accelerators, to challenge Nvidia which dominates the market...
#
# Title: Time travel? Or, just clever technology
# Description: How does SyncDNA actually work? Learn how we solve a seemingly impossible problem.
#
# Title: Apple and Google Pull ICE-Tracking Apps, Bowing to DOJ Pressure
# Description: Plus: China sentences scam bosses to death, Europe is ramping up its plans to build a “drone wall” to protect against Russian airspace violations, and more.
#
# Title: Xiaomi 17 Pro and 17 Pro Max: Specs, Release Date, Price, Features
# Description: Following the 15 Ultra, the new Xiaomi 17 Pro Max sounds and looks very familiar to a certain iPhone, but with a twist.
#
# Title: Meta’s Smart Glasses Might Make You Smarter. They’ll Certainly Make You More Awkward
# Description: Meta CEO Mark Zuckerberg claims anyone not wearing smart glasses will be at a “cognitive disadvantage” in the future. But you'll have to pay a hefty social price for those added smarts.
#
# Title: Everything Amazon Announced Today at Its Fall Hardware Event (2025)
# Description: Amazon's next-gen Alexa+ chatbot is now available in four new Echo devices and a bevy of Ring cameras. The company also debuted three new Kindle Scribe tablets, one with a color screen.
#
# Title: Joby Aviation (JOBY) Completes Landmark U.S. Defense Exercise Using Autonomous Flight Technology
# Description: None
#
# Title: Nvidia spent over $900 million to hire Enfabrica CEO, license technology, CNBC reports
# Description: The deal closed last week and Sankar has already joined Nvidia.  Enfabrica, a Silicon Valley-based chip startup, is tackling one of the biggest technical...
#
# Title: Peter Thiel’s Antichrist Lectures Met With Protestors Who Seem to Think He’s the Antichrist
# Description: The Palantir mogul began his devil-themed seminar series this week.
#
# Title: AI Finds its Niche: Writing Corporate Press Releases
# Description: Hopefully it got the numbers right.
#
# Title: Retail Stores May Soon Use Drones to Chase Thieves
# Description: Flock Safety's high-tech drones designed for cops are now being offered to private security firms.
#
# Title: SB 53, the landmark AI transparency bill, is now law in California
# Description: Senate Bill 53, the landmark AI transparency bill that has divided AI companies and made headlines for months, is now officially law in California.  On Monday, California governor Gavin Newsom signed the “Transparency in Frontier Artificial Intelligence Act,”…
#
# Title: The US government is taking a second stab at breaking up Google
# Description: Starting Monday, the US government will get another crack at convincing a federal judge to break up Google, after a different judge decided to keep it intact despite finding it to be a monopolist. Lawyers for Google and the Justice Department will return to a…
#
# Title: Meta’s new smart glasses are coming this week
# Description: Meta’s next big Connect conference is nearly here, and this year, we’re expecting to see a lot of news about glasses. AI-focused hardware is all the rage, and Meta arguably already has the best gadgets around in its Ray-Ban and Oakley glasses. At this year’s …
#
# Title: Tile’s lack of encryption could make tracker owners vulnerable to stalking
# Description: Security researchers are shining the spotlight on a serious security vulnerability that could enable stalkers to track victims using their own Tile tags, as well as other unwanted violations of security and privacy. Research outlined by Wired shows that Tile’…
#
# Title: SoundHound AI (SOUN) Stock Trades Up, Here Is Why
# Description: Shares of voice AI technology company SoundHound AI (NASDAQ:SOUN) jumped 2.1% in the afternoon session after it received continued positive commentary from...
#
# Title: Why Is SoundHound AI (SOUN) Stock Soaring Today
# Description: Shares of voice AI technology company SoundHound AI (NASDAQ:SOUN) jumped 7% in the afternoon session after it experienced continued positive sentiment...
#
# Title: Micron, The RealReal, Beyond Meat: Top Analyst Calls
# Description: Yahoo Finance senior reporter Allie Canal tracks several of the day's top analyst calls on trending stocks, including Micron Technology (MU), The RealReal...
#
# Title: MLB will use robot umpires beginning next season
# Description: Major League Baseball will use so-called robot umpires at home plate beginning in 2026, the league announced today. The system has been tested in minor league games (as explained in this video, included below), spring training, and events like the 2025 All-St…
#
# Title: Apple’s future MacBook Pro might have a touchscreen
# Description: The next generation of Apple’s MacBook Pro laptops could be the first to feature a touchscreen display, according to supply chain analyst Ming-Chi Kuo. The change could apply to OLED MacBook Pro models that are expected to enter production by late 2026, Kuo r…
#
# Title: Bang & Olufsen’s new earbuds will cost you more than the latest iPhone
# Description: Bang & Olufsen’s latest Beo Grace earbuds offer a flashy aluminum design and the brand’s “most advanced” active noise cancellation for a staggering $1,500. These pricey new buds pump sound through 12mm titanium drivers, featuring ANC powered by six microphone…
#
# Title: New FAA program will let eVTOL startups test some operations before full certification
# Description: It's a major change that paves the way for electric air taxi startups to perform more robust demonstrations of their technology before they begin any...
#
# Title: Zoom’s CEO agrees with Bill Gates, Jensen Huang, and Jamie Dimon: A 3-day workweek is coming soon thanks to AI
# Description: Zoom leader Eric Yuan admits that the technology will erase some human jobs—but those who keep their jobs will enjoy fewer working days.
#
# Title: AI expert says it’s ‘not a question’ that AI will take over all jobs—but people will have 80 hours a week of free time
# Description: Dr. Roman Yampolskiy, a professor of computer science and leading voice in AI safety, says the technology will take over 99% of jobs in the next five years.
#
# Title: UK Has Good Tech Talent Pool, Paid's Manny Medina Says
# Description: The rise of AI agents has brought with it the question of how much developers of the technology should be charging their customers. The traditional software ...
#
# Title: Australian watchdog says budget retailer Kmart breached privacy with facial recognition tech
# Description: The Office of the Australian Information Commissioner (OAIC) found that Kmart did not notify shoppers or seek their consent to use the technology to collect ...
#
# Title: BYD’s $45 Billion Stock Wipeout Raises Doubts on China Outlook
# Description: At the same time, rivals including Geely Automobile Holdings Ltd. and Zhejiang Leapmotor Technology Co. are gaining ground.  “While I believe investors...
#
# Title: Nuclear fusion, the ‘holy grail’ of power, was always 30 years away—now it’s a matter of when, not if, fusion comes online to power AI
# Description: Fusion has the potential to solve the world's energy demand and climate goals, but questions remain about crossing the technology finish line and scaling up ...
#
# Title: Dialing It In: A 3D-Printed Knob with Touchscreen Flair
# Description: Knobs are ubiquitous in technology user interfaces, but touchscreens are increasingly replacing them for interface controls. The latest project from [upir] combines a rotating knob with a touchscreen for a …read more
#
# Title: The Impending CRT Display Revival Will Be Televised
# Description: Until the 2000s vacuum tubes practically ruled the roost. Even if they had surrendered practically fully to semiconductor technology like integrated circuits, there was no escaping them in everything from …read more
#
# Title: A Love Letter to Internet Relay Chat
# Description: Although kids these days tend to hang out on so-called “Social Media”, Internet Relay Chat (IRC) was first, by decades. IRC is a real-time communication technology that allows people to …read more
#
# Title: YouTube… Over Dial Up
# Description: In the days of yore, computers would scream strange sounds as they spoke with each other over phone lines. Of course, this is dial up, the predecessor to modern internet technology, offering laugha…
#
# Title: Fox News AI Newsletter: Melania Trump puts AI front and center
# Description: Fox News' AI newsletter brings you the latest on technology advancements around artificial intelligence.
#
# Title: ‘Godfather of AI’ says the technology will create massive unemployment and send profits soaring — ‘that is the capitalist system’
# Description: "We are at a point in history where something amazing is happening, and it may be amazingly good, and it may be amazingly bad."
#
# Title: When I was building my career, I relied on technology to keep my kids company. I realized I was losing them.
# Description: I was struggling to juggle motherhood and career, so I let my kids use tech to keep them company. They started to lose interest in conversation.
#
# Title: President Trump Signs Technology Prosperity Deal with United Kingdom
# Description: Today, President Donald J. Trump and Prime Minister Keir Starmer signed the Technology Prosperity Deal, a landmark science and technology agreement that
#
# Title: Sierra CEO Bret Taylor on why the AI bubble feels like the dotcom boom
# Description: Welcome to Decoder. This is Alex Heath. For my final episode as your Thursday guest host, I recently sat down with Bret Taylor, the CEO of AI startup Sierra and the chairman of OpenAI, for a live event in San Francisco, California, hosted by Alix Partners.  V…
#
# Title: Cassette Logic: technology that never dies but is already dead
# Description: A song about something that never dies but is already dead turned up on a thirty-year-old mixtape this morning. Cassette has a way of delivering what you would never think to ask for.
#
# Title: MIT technology can see microbes from 90 meters away
# Description: Biotechnology needs more and better transducers.
#
# Title: Disrupting the DRAM roadmap with capacitor-less IGZO-DRAM technology
# Description: This technology review explains hpw 2T0C IGZO-based DRAM opens doors to high-density 3D DRAM and embedded DRAM.
#
# Title: Anker is upgrading its global ambitions—with AI and a stair-climbing robovac system
# Description: From phone chargers to robotics and large AI models.
#
# Title: How Republicans Plan to Use AI for 2026 (Even If It’s Too Woke)
# Description: Did your candidate take a photo with a tattooed American? Just remove the tat with AI.
#
# Title: This Top Computer and Technology Stock is a #1 (Strong Buy): Why It Should Be on Your Radar
# Description: The Zacks Rank offers investors a way to easily find top-rated stocks and build a winning investment portfolio. Here's why you should take advantage.
#
# Title: Citi poaches IBM exec to accelerate its AI ambitions: See the memo
# Description: The bank has been announcing a series of leaders to help steer its rapidly expanding AI strategy. Shobhit Varshney, from IBM, is the latest.
#
# Title: Tesla's Lead in Car Software Updates Remains Unchallenged
# Description: No automaker has matched Tesla's ability to deliver over-the-air software updates despite years of effort and billions in spending. Tesla introduced the technology in 2012 and issued 42 updates within six months, Jean-Marie Lapeyre, Capgemini's chief technolo…
#
# Title: Moderna CEO Responds to RFK Jr.’s Crusade Against the Covid-19 Vaccine
# Description: Speaking at a WIRED event Tuesday, Moderna CEO Stéphane Bancel said he was “encouraged” by the company’s dialogue with the FDA—but acknowledged recent setbacks.
